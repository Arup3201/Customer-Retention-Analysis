# %% [markdown]
# # Customer Retention Analysis

# %% [markdown]
# ## Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib import colors
import seaborn as sns
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

from sklearn.metrics import accuracy_score, confusion_matrix, ConfusionMatrixDisplay, f1_score

# %% [markdown]
# Basic settings of dataframe and plots

# %%
# Pandas dataframes show all rows and columns without skiping
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# Matplotlib setting of figsize and dpi
mpl.rcParams['figure.figsize'] = [16, 5]
mpl.rcParams['figure.dpi'] = 200

# Palette and cmap to use in seaborn plots
palette = ["#fab005", "#12b886", "#4c6ef5", "#7950f2","#be4bdb", "#d6336c"]
cmap = colors.ListedColormap(["#fab005", "#12b886", "#4c6ef5", "#7950f2","#be4bdb", "#d6336c"])

# Seaborn plot styles
sns.set_style(style='darkgrid')
sns.set(rc={'font.family': 'Verdana', 'font.size': 16})

# %matplotlib inline

# %% [markdown]
# ## Dataset

# %%
data = pd.read_csv('./data/Bank Customer Churn Prediction.csv')

# %%
data.head()
# Out:
#    customer_id  credit_score country  gender  age  tenure    balance  \
# 0     15634602           619  France  Female   42       2       0.00
# 1     15647311           608   Spain  Female   41       1   83807.86
# 2     15619304           502  France  Female   42       8  159660.80
# 3     15701354           699  France  Female   39       1       0.00
# 4     15737888           850   Spain  Female   43       2  125510.82
#
#    products_number  credit_card  active_member  estimated_salary  churn
# 0                1            1              1         101348.88      1
# 1                1            0              1         112542.58      0
# 2                3            1              0         113931.57      1
# 3                2            0              0          93826.63      0
# 4                1            1              1          79084.10      0

# %%
data.shape
# Out:
# (10000, 12)

# %%
# Make a copy so that when any facing any error, we can run this cell and take the data without reimporting the whole csv
df = data.copy()

# %% [markdown]
# ## Data Cleaning

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customer_id       10000 non-null  int64
#  1   credit_score      10000 non-null  int64
#  2   country           10000 non-null  object
#  3   gender            10000 non-null  object
#  4   age               10000 non-null  int64
#  5   tenure            10000 non-null  int64
#  6   balance           10000 non-null  float64
#  7   products_number   10000 non-null  int64
#  8   credit_card       10000 non-null  int64
#  9   active_member     10000 non-null  int64
#  10  estimated_salary  10000 non-null  float64
#  11  churn             10000 non-null  int64
# dtypes: float64(2), int64(8), object(2)
# memory usage: 937.6+ KB

# %%
sns.boxplot(x=df['credit_score'], color=palette[0])
plt.show()

# %%
sns.boxplot(x=df['age'], color=palette[0])
plt.show()

# %%
sns.boxplot(x=df['tenure'], color=palette[0])
plt.show()

# %%
sns.boxplot(x=df['balance'], color=palette[0])
plt.show()

# %%
sns.boxplot(x=df['estimated_salary'], color=palette[0])
plt.show()

# %%
df_cleaned = df.copy()

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customer_id       10000 non-null  int64
#  1   credit_score      10000 non-null  int64
#  2   country           10000 non-null  object
#  3   gender            10000 non-null  object
#  4   age               10000 non-null  int64
#  5   tenure            10000 non-null  int64
#  6   balance           10000 non-null  float64
#  7   products_number   10000 non-null  int64
#  8   credit_card       10000 non-null  int64
#  9   active_member     10000 non-null  int64
#  10  estimated_salary  10000 non-null  float64
#  11  churn             10000 non-null  int64
# dtypes: float64(2), int64(8), object(2)
# memory usage: 937.6+ KB

# %%
df_cleaned = df_cleaned[df_cleaned['credit_score']>390]
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9983 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customer_id       9983 non-null   int64
#  1   credit_score      9983 non-null   int64
#  2   country           9983 non-null   object
#  3   gender            9983 non-null   object
#  4   age               9983 non-null   int64
#  5   tenure            9983 non-null   int64
#  6   balance           9983 non-null   float64
#  7   products_number   9983 non-null   int64
#  8   credit_card       9983 non-null   int64
#  9   active_member     9983 non-null   int64
#  10  estimated_salary  9983 non-null   float64
#  11  churn             9983 non-null   int64
# dtypes: float64(2), int64(8), object(2)
# memory usage: 1013.9+ KB

# %%
df_cleaned = df_cleaned[df_cleaned['age']<65]
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9701 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customer_id       9701 non-null   int64
#  1   credit_score      9701 non-null   int64
#  2   country           9701 non-null   object
#  3   gender            9701 non-null   object
#  4   age               9701 non-null   int64
#  5   tenure            9701 non-null   int64
#  6   balance           9701 non-null   float64
#  7   products_number   9701 non-null   int64
#  8   credit_card       9701 non-null   int64
#  9   active_member     9701 non-null   int64
#  10  estimated_salary  9701 non-null   float64
#  11  churn             9701 non-null   int64
# dtypes: float64(2), int64(8), object(2)
# memory usage: 985.3+ KB

# %%
df = df_cleaned.copy()

# %% [markdown]
# ## Exploratory data analysis

# %%
df['country'].unique()
# Out:
# array(['France', 'Spain', 'Germany'], dtype=object)

# %%
df['gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
df['products_number'].unique()
# Out:
# array([1, 3, 2, 4], dtype=int64)

# %% [markdown]
# *Finding*
# 1. ABC bank is active in 3 countries of europe, `France`, `Spain` and `Germany`.
# 2. ABC bank deals with 2 genders, `Male` and `Female`.
# 3. ABC bank provides 4 services or products, `1`, `2`, `3` and `4`.

# %%
sns.countplot(x=df['country'], color=palette[0])
plt.show()

# %%
sns.countplot(x=df['gender'], color=palette[0])
plt.show()

# %%
sns.countplot(x=df['tenure'], color=palette[0])
plt.show()

# %%
sns.countplot(x=df['products_number'], color=palette[0])
plt.show()

# %%
sns.countplot(x=df['credit_card'], color=palette[0])
plt.show()

# %%
sns.countplot(x=df['active_member'], color=palette[0])
plt.show()

# %% [markdown]
# *Findings*
# 1. Most customers are using the ABC bank branch of `France`. `Spain` and `Germany` have almost same amount of customers.
# 2. Although there is not much difference in `Male` and `Female` customer counts in the ABC bank, still there are more `Male` customers than `Female`.
# 3. Products with number `1` and `2` are the most purchased product. Other 2 products are rarely purchased.
# 4. More than 6000 customers are using credit card. And more than 2000 customers are not using credit card.
# 5. Active and non-active customer count is very close.

# %%
sizes = [df.churn[df['churn']==1].count(), df.churn[df['churn']==0].count()]
labels = ['Churned', 'Not Churned']
figure, axes = plt.subplots()
axes.pie(sizes, labels=labels, autopct = '%1.2f%%', colors=palette)
plt.legend(loc='upper right')
plt.title("Churned VS Not Churned", size = 12)
plt.show()

# %% [markdown]
# *Findings*
# - More than 20% customers are churning.

# %% [markdown]
# ### Feature effect on churn rate

# %%
df.columns
# Out:
# Index(['customer_id', 'credit_score', 'country', 'gender', 'age', 'tenure',
#        'balance', 'products_number', 'credit_card', 'active_member',
#        'estimated_salary', 'churn'],
#       dtype='object')

# %% [markdown]
# #### Continuous features
#
# - credit_score
# - age
# - tenure
# - balance
# - estimated_salary

# %%
sns.histplot(x=df['credit_score'], hue=df['churn'], kde=True, palette=palette[:2])
plt.show()

# %%
sns.histplot(x=df['age'], hue=df['churn'], kde=True, palette=palette[:2])
plt.show()

# %%
sns.histplot(x=df['balance'], hue=df['churn'], kde=True, palette=palette[:2])
plt.show()

# %%
sns.histplot(x=df['estimated_salary'], hue=df['churn'], kde=True, palette=palette[:2])
plt.show()

# %% [markdown]
# *Findings*
# 1. `age` have a clear impact on the churn rate of users. Other continuous features do not contribute much on the churn rate of users. Because the churn rate is exactly proportionate with the volume of customer in that bar.
# 2. Users with more `age` are more likely to churn than young users.

# %% [markdown]
# #### Categorical features
#
# - country
# - gender
# - tenure
# - products_number
# - credit_card
# - active_member

# %%
sns.countplot(x=df['country'], hue=df['churn'], palette=palette[:2])
plt.show()

# %%
sns.countplot(x=df['gender'], hue=df['churn'], palette=palette[:2])
plt.show()

# %%
sns.countplot(x=df['tenure'], hue=df['churn'], palette=palette[:2])
plt.show()

# %%
sns.countplot(x=df['products_number'], hue=df['churn'], palette=palette[:2])
plt.show()

# %%
sns.countplot(x=df['credit_card'], hue=df['churn'], palette=palette[:2])
plt.show()

# %%
sns.countplot(x=df['active_member'], hue=df['churn'], palette=palette[:2])
plt.show()

# %% [markdown]
# *Finding*
# 1. Highest churn rate is at `Germany` and `France` has lowest churn rate.
# 2. `Female`s are more likely to churn than `Male`s.
# 3. `tenure` has very less impact on churn rate.
# 4. Product 3 and 4 are more likely to churn in fact most customers who buy these products churn. Product 2 has very less churn rate.
# 5. Active members are less likely to churn.

# %% [markdown]
# ## Feature engineering

# %%
df_drop = df.drop(['customer_id'], axis=1)

# %%
df = df_drop.copy()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9701 entries, 0 to 9999
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   credit_score      9701 non-null   int64
#  1   country           9701 non-null   object
#  2   gender            9701 non-null   object
#  3   age               9701 non-null   int64
#  4   tenure            9701 non-null   int64
#  5   balance           9701 non-null   float64
#  6   products_number   9701 non-null   int64
#  7   credit_card       9701 non-null   int64
#  8   active_member     9701 non-null   int64
#  9   estimated_salary  9701 non-null   float64
#  10  churn             9701 non-null   int64
# dtypes: float64(2), int64(7), object(2)
# memory usage: 909.5+ KB

# %%
X = df.iloc[:, :10].values
y = df.iloc[:, 10].values

# %%
type(X), type(y)
# Out:
# (numpy.ndarray, numpy.ndarray)

# %%
le_country = LabelEncoder()
X[:, 1] = le_country.fit_transform(X[:, 1])

le_gender = LabelEncoder()
X[:, 2] = le_gender.fit_transform(X[:, 2])

# %%
X[0]
# Out:
# array([619, 0, 0, 42, 2, 0.0, 1, 1, 1, 101348.88], dtype=object)

# %%
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
X[0]
# Out:
# array([-0.33005253, -0.90133768, -1.0964808 ,  0.44349501, -1.04283734,
#        -1.22784484, -0.91325934,  0.64674172,  0.98943831,  0.02304572])

# %% [markdown]
# ## Customer Churn Prediction

# %% [markdown]
# ### Train Test split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=2023)

# %% [markdown]
# ### Naive Bayes

# %%
nb_model = GaussianNB()

# %%
nb_model.fit(X, y)
# Out:
# GaussianNB()

# %%
y_pred = nb_model.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print(f"Accuracy: {accuracy}")
print(f"f1_score: {f1}")
# Out:
# Accuracy: 0.8381999312950876
# f1_score: 0.47955801104972373

# %%
labels = [0, 1]
cm = confusion_matrix(y_test, y_pred, labels=labels)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)
disp.plot()

# %% [markdown]
# ### Logistic Regression

# %% [markdown]
# ### Decision Tree

# %% [markdown]
# ### Random Forest

# %% [markdown]
# ### KNN

# %% [markdown]
# ### SVM

# %% [markdown]
# ## Feature importance analysis

# %% [markdown]
# ## Identifying key drivers of churn

# %% [markdown]
# ## Retention strategy optimization
